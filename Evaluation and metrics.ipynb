# %% [markdown]
# # Evaluation and metrics

# %% [markdown]
# ### Imports

# %%
import re
import docx
import numpy as np
import pandas as pd
from collections import defaultdict
from IPython.display import display, Markdown

# %% [markdown]
# ## Load annotated documents

# %%
def extract_comments_and_labels(doc, is_chatgpt=False):
    comments_and_labels = []
    current_text = ""

    for paragraph in doc.paragraphs:
        for i, run in enumerate(paragraph.runs):
            if run.comments:
                text = run.text if is_chatgpt else paragraph.runs[i - 1].text
                if current_text:
                    comments_and_labels.append((current_text if is_chatgpt else current_text[:-len(text)], None))
                    current_text = ""
                labels = ', '.join([comment.text for comment in run.comments]).split(', ')
                if is_chatgpt:
                    labels = [re.sub(r" \(confidence:.*?\)", "", label) for label in labels]
                comments_and_labels.append((text, labels))
            else:
                current_text += run.text
        current_text += "\n"

    if current_text:
        comments_and_labels.append((current_text, None))

    return comments_and_labels

# %%
def translate_labels_into_spans(comments_and_labels):
    spans = []
    current_len = 0
    for unlabeled_span, labeled_span in zip(comments_and_labels[::2], comments_and_labels[1::2]):
        current_len += len(unlabeled_span[0])
        for label in labeled_span[1]:
            spans.append((label, (current_len, current_len + len(labeled_span[0]))))
        current_len += len(labeled_span[0])
    return spans

# %%
input_files = ['trump_ground_truth.docx', 'biden_ground_truth.docx', 'putin_ground_truth.docx']

# %% [markdown]
# ### Load ground truth

# %%
ground_truth = {}

for input_file in input_files:
    speaker = input_file.split("_")[0]
    ground_truth[speaker] = []
    original_doc = docx.Document(input_file)
    labs = extract_comments_and_labels(original_doc)
    ground_truth[speaker] += labs
    ground_truth[speaker] = translate_labels_into_spans(ground_truth[speaker])

# %% [markdown]
# ### Load documents annotated by ChatGPT

# %%
ai_labels = {}

for input_file in input_files:
    speaker = input_file.split("_")[0]
    ai_labels[speaker] = []
    original_doc = docx.Document(speaker + "_chatgpt_final.docx")
    labs = extract_comments_and_labels(original_doc, is_chatgpt=True)
    ai_labels[speaker] += labs
    ai_labels[speaker] = translate_labels_into_spans(ai_labels[speaker])

# %% [markdown]
# ## Evaluate function

# %%
def jaccard_similarity(a, b):
    intersection = max(0, min(a[1], b[1]) - max(a[0], b[0]))
    union = max(a[1], b[1]) - min(a[0], b[0])
    return intersection / union

def evaluate_spans(ground_truth, ai_spans):
    label_metrics = defaultdict(lambda: {'tp': 0, 'fp': 0, 'fn': 0})
    threshold = 0.5

    for label, span in ground_truth:
        matched = False
        for ai_label, ai_span in ai_spans:
            if label == ai_label and jaccard_similarity(span, ai_span) >= threshold:
                label_metrics[label]['tp'] += 1
                matched = True
                ai_spans.remove((ai_label, ai_span))
                break
        if not matched:
            label_metrics[label]['fn'] += 1

    for ai_label, _ in ai_spans:
        label_metrics[ai_label]['fp'] += 1

    for label, metrics in label_metrics.items():
        precision = metrics['tp'] / (metrics['tp'] + metrics['fp']) if metrics['tp'] + metrics['fp'] > 0 else 0
        recall = metrics['tp'] / (metrics['tp'] + metrics['fn']) if metrics['tp'] + metrics['fn'] > 0 else 0
        f1_score = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
        label_metrics[label]['precision'] = precision * 100
        label_metrics[label]['recall'] = recall * 100
        label_metrics[label]['f1_score'] = f1_score * 100

    return label_metrics

# %% [markdown]
# ## Metrics calculation and display

# %%
def display_metrics(eval_result):
    metrics_df = pd.DataFrame(eval_result).transpose()
    metrics_df = metrics_df.astype({"tp":"int", "fp":"int", "fn":"int"})
    metrics_df.sort_index(inplace=True)
    metrics_df.columns = ["True positive", "False positive", "False negative", "Precision", "Recall", "F1 Score"]
    return metrics_df

# %%
def weighted_average_metrics(df):
    # Calculate the number of ground truth labels for each category
    ground_truth_counts = df['True positive'] + df['False negative']
    
    # Calculate the weights for each category
    weights = ground_truth_counts / ground_truth_counts.sum()
    
    # Calculate the weighted average precision, recall, and F1 score
    weighted_precision = (df['Precision'] * weights).sum()
    weighted_recall = (df['Recall'] * weights).sum()
    weighted_f1_score = (df['F1 Score'] * weights).sum()
    
    return weighted_precision, weighted_recall, weighted_f1_score

# %%
metrics = {}

# %%
speaker = "trump"
metrics[speaker] = {}
metrics[speaker]["by_labels"] = display_metrics(evaluate_spans(ground_truth[speaker], ai_labels[speaker]))
metrics[speaker]["average"] = weighted_average_metrics(metrics[speaker]["by_labels"])

display(Markdown(f'### {speaker.capitalize()} Text Metrics'))
display(metrics[speaker]["by_labels"])
display(Markdown(f'**Weighted Precision:** {metrics[speaker]["average"][0]}'))
display(Markdown(f'**Weighted Recall:** {metrics[speaker]["average"][1]}'))
display(Markdown(f'**Weighted F1 Score:** {metrics[speaker]["average"][2]}'))
# Out:
# ### Trump Text Metrics
#                                 True positive  False positive  False negative  \
# accusation                                  0               0               2
# ad hominem                                  0               1               0
# appeal to a sense of community              0               0               4
# appeal to authority                         0               1               0
# appeal to emotion                           0               6               0
# appeal to emotions                          0               3               3
# appeal to equality                          0               0               2
# appeal to fear                              0               2               0
# appeal to history                           0               0               2
# appeal to self-interest                     0               1               0
# appeal to values                            1               8               7
# bandwagon                                   0               4               0
# blame                                       0               1               0
# causation without correlation               0               1               0
# comparison                                  0               1               5
# conspiracy theory                           0               1               0
# credibility                                 0               3               0
# criticizing the opposition                  0               3               0
# demonization                                0               9               0
# emotional appeal                            0               4               0
# emotional words                             0               4               0
# euphemism                                   0               4               0
# exaggeration                                1              20               5
# exceptionalism                              0               1               0
# exclusion                                   0               2               0
# false cause                                 0               2               0
# false comparison                            0               2               0
# false dilemma                               0               1               0
# fear                                        0              15               0
# fear-mongering                              0               9               0
# glittering generalities                     0              10               0
# glittering generality                       0               8               0
# hyperbole                                   0               4               0
# indication of certainty                     0               0              12
# labeling                                    0              12               1
# loaded language                             0               6               0
# loaded question                             0               2               0
# metaphor                                    0               1               0
# misrepresentation                           0               5               0
# name calling                                0               5               0
# negative other-presentation                 0               0               8
# none                                        0               1               0
# oversimplification                          0               2               0
# patriotic appeal                            0               6               0
# personal anecdote                           0               1               0
# plain folks                                 0               1               0
# polarization                                2               9               4
# positive self-presentation                  0               0               1
# rallying around the flag                    0               1               4
# reference to authority                      0               0               2
# repetition                                  0               7               1
# scapegoating                                0               2               0
# simplification                              0               1               0
# straw man                                   0               4               0
# testimonial                                 0              10               0
# transfer of responsibility                  0               0               4
# us vs them                                  0               1               0
# victimhood                                  0               1               0
# victimization                               0               2               1
#
#                                 Precision     Recall   F1 Score
# accusation                       0.000000   0.000000   0.000000
# ad hominem                       0.000000   0.000000   0.000000
# appeal to a sense of community   0.000000   0.000000   0.000000
# appeal to authority              0.000000   0.000000   0.000000
# appeal to emotion                0.000000   0.000000   0.000000
# appeal to emotions               0.000000   0.000000   0.000000
# appeal to equality               0.000000   0.000000   0.000000
# appeal to fear                   0.000000   0.000000   0.000000
# appeal to history                0.000000   0.000000   0.000000
# appeal to self-interest          0.000000   0.000000   0.000000
# appeal to values                11.111111  12.500000  11.764706
# bandwagon                        0.000000   0.000000   0.000000
# blame                            0.000000   0.000000   0.000000
# causation without correlation    0.000000   0.000000   0.000000
# comparison                       0.000000   0.000000   0.000000
# conspiracy theory                0.000000   0.000000   0.000000
# credibility                      0.000000   0.000000   0.000000
# criticizing the opposition       0.000000   0.000000   0.000000
# demonization                     0.000000   0.000000   0.000000
# emotional appeal                 0.000000   0.000000   0.000000
# emotional words                  0.000000   0.000000   0.000000
# euphemism                        0.000000   0.000000   0.000000
# exaggeration                     4.761905  16.666667   7.407407
# exceptionalism                   0.000000   0.000000   0.000000
# exclusion                        0.000000   0.000000   0.000000
# false cause                      0.000000   0.000000   0.000000
# false comparison                 0.000000   0.000000   0.000000
# false dilemma                    0.000000   0.000000   0.000000
# fear                             0.000000   0.000000   0.000000
# fear-mongering                   0.000000   0.000000   0.000000
# glittering generalities          0.000000   0.000000   0.000000
# glittering generality            0.000000   0.000000   0.000000
# hyperbole                        0.000000   0.000000   0.000000
# indication of certainty          0.000000   0.000000   0.000000
# labeling                         0.000000   0.000000   0.000000
# loaded language                  0.000000   0.000000   0.000000
# loaded question                  0.000000   0.000000   0.000000
# metaphor                         0.000000   0.000000   0.000000
# misrepresentation                0.000000   0.000000   0.000000
# name calling                     0.000000   0.000000   0.000000
# negative other-presentation      0.000000   0.000000   0.000000
# none                             0.000000   0.000000   0.000000
# oversimplification               0.000000   0.000000   0.000000
# patriotic appeal                 0.000000   0.000000   0.000000
# personal anecdote                0.000000   0.000000   0.000000
# plain folks                      0.000000   0.000000   0.000000
# polarization                    18.181818  33.333333  23.529412
# positive self-presentation       0.000000   0.000000   0.000000
# rallying around the flag         0.000000   0.000000   0.000000
# reference to authority           0.000000   0.000000   0.000000
# repetition                       0.000000   0.000000   0.000000
# scapegoating                     0.000000   0.000000   0.000000
# simplification                   0.000000   0.000000   0.000000
# straw man                        0.000000   0.000000   0.000000
# testimonial                      0.000000   0.000000   0.000000
# transfer of responsibility       0.000000   0.000000   0.000000
# us vs them                       0.000000   0.000000   0.000000
# victimhood                       0.000000   0.000000   0.000000
# victimization                    0.000000   0.000000   0.000000
# **Weighted Precision:** 3.14654481321148
# **Weighted Recall:** 5.555555555555555
# **Weighted F1 Score:** 3.8852578068264343

# %%
speaker = "biden"
metrics[speaker] = {}
metrics[speaker]["by_labels"] = display_metrics(evaluate_spans(ground_truth[speaker], ai_labels[speaker]))
metrics[speaker]["average"] = weighted_average_metrics(metrics[speaker]["by_labels"])

display(Markdown(f'### {speaker.capitalize()} Text Metrics'))
display(metrics[speaker]["by_labels"])
display(Markdown(f'**Weighted Precision:** {metrics[speaker]["average"][0]}'))
display(Markdown(f'**Weighted Recall:** {metrics[speaker]["average"][1]}'))
display(Markdown(f'**Weighted F1 Score:** {metrics[speaker]["average"][2]}'))
# Out:
# ### Biden Text Metrics
#                                 True positive  False positive  False negative  \
# accusation                                  0               0               8
# antithesis                                  0               1               0
# appeal to a sense of community              0               0               7
# appeal to authority                         0               2               0
# appeal to common folks                      0               1               0
# appeal to consequences                      0               5               0
# appeal to emotions                          0               0              11
# appeal to equality                          0               0               2
# appeal to fear                              0               2               0
# appeal to history                           0               0               2
# appeal to patriotism                        0               4               0
# appeal to values                            1              11              10
# cognitive bias                              0               2               0
# common humanity                             0               1               0
# comparison                                  0               1               4
# contrast                                    0               4               0
# counterfactuals                             0               0               2
# credibility                                 0               2               0
# criticizing opponent                        0               3               0
# emotional appeal                            0               1               0
# evidentiality                               0               0               1
# exaggeration                                0               3               0
# fear                                        0               1               0
# high level of certainty                     0               0               5
# humblebrag                                  0               1               0
# indication of certainty                     0               0               2
# metaphor                                    0               2               0
# negative comparison                         0               1               0
# negative other-presentation                 0               0               2
# number game                                 0               0               3
# patriotic appeal                            0               7               0
# polarization                                0               2               6
# positive self-presentation                  0               0               1
# preemptive defense                          0               1               0
# rallying around the flag                    0               7               4
# reference to authority                      0               0               2
# reference to historic events                0               0               1
# repetition                                  0               7               1
# rhetorical question                         0               1               0
# testimonial                                 0               3               0
# use of antithesis                           0               1               0
# use of authority                            0               1               0
# use of emotive language                     0               5               0
# use of inclusive language                   0               6               0
# use of metaphor                             0               1               0
# use of personal anecdote                    0               1               0
# use of slogan                               0               3               0
# use of strawman                             0               1               0
#
#                                 Precision    Recall  F1 Score
# accusation                       0.000000  0.000000  0.000000
# antithesis                       0.000000  0.000000  0.000000
# appeal to a sense of community   0.000000  0.000000  0.000000
# appeal to authority              0.000000  0.000000  0.000000
# appeal to common folks           0.000000  0.000000  0.000000
# appeal to consequences           0.000000  0.000000  0.000000
# appeal to emotions               0.000000  0.000000  0.000000
# appeal to equality               0.000000  0.000000  0.000000
# appeal to fear                   0.000000  0.000000  0.000000
# appeal to history                0.000000  0.000000  0.000000
# appeal to patriotism             0.000000  0.000000  0.000000
# appeal to values                 8.333333  9.090909  8.695652
# cognitive bias                   0.000000  0.000000  0.000000
# common humanity                  0.000000  0.000000  0.000000
# comparison                       0.000000  0.000000  0.000000
# contrast                         0.000000  0.000000  0.000000
# counterfactuals                  0.000000  0.000000  0.000000
# credibility                      0.000000  0.000000  0.000000
# criticizing opponent             0.000000  0.000000  0.000000
# emotional appeal                 0.000000  0.000000  0.000000
# evidentiality                    0.000000  0.000000  0.000000
# exaggeration                     0.000000  0.000000  0.000000
# fear                             0.000000  0.000000  0.000000
# high level of certainty          0.000000  0.000000  0.000000
# humblebrag                       0.000000  0.000000  0.000000
# indication of certainty          0.000000  0.000000  0.000000
# metaphor                         0.000000  0.000000  0.000000
# negative comparison              0.000000  0.000000  0.000000
# negative other-presentation      0.000000  0.000000  0.000000
# number game                      0.000000  0.000000  0.000000
# patriotic appeal                 0.000000  0.000000  0.000000
# polarization                     0.000000  0.000000  0.000000
# positive self-presentation       0.000000  0.000000  0.000000
# preemptive defense               0.000000  0.000000  0.000000
# rallying around the flag         0.000000  0.000000  0.000000
# reference to authority           0.000000  0.000000  0.000000
# reference to historic events     0.000000  0.000000  0.000000
# repetition                       0.000000  0.000000  0.000000
# rhetorical question              0.000000  0.000000  0.000000
# testimonial                      0.000000  0.000000  0.000000
# use of antithesis                0.000000  0.000000  0.000000
# use of authority                 0.000000  0.000000  0.000000
# use of emotive language          0.000000  0.000000  0.000000
# use of inclusive language        0.000000  0.000000  0.000000
# use of metaphor                  0.000000  0.000000  0.000000
# use of personal anecdote         0.000000  0.000000  0.000000
# use of slogan                    0.000000  0.000000  0.000000
# use of strawman                  0.000000  0.000000  0.000000
# **Weighted Precision:** 1.222222222222222
# **Weighted Recall:** 1.3333333333333335
# **Weighted F1 Score:** 1.2753623188405796

# %%
speaker = "putin"
metrics[speaker] = {}
metrics[speaker]["by_labels"] = display_metrics(evaluate_spans(ground_truth[speaker], ai_labels[speaker]))
metrics[speaker]["average"] = weighted_average_metrics(metrics[speaker]["by_labels"])

display(Markdown(f'### {speaker.capitalize()} Text Metrics'))
display(metrics[speaker]["by_labels"])
display(Markdown(f'**Weighted Precision:** {metrics[speaker]["average"][0]}'))
display(Markdown(f'**Weighted Recall:** {metrics[speaker]["average"][1]}'))
display(Markdown(f'**Weighted F1 Score:** {metrics[speaker]["average"][2]}'))
# Out:
# ### Putin Text Metrics
#                                 True positive  False positive  False negative  \
# accusation                                  0               2               4
# ad hominem                                  0               3               0
# appeal to a sense of community              0               0               1
# appeal to authority                         0               2               0
# appeal to consequences                      0               2               0
# appeal to emotion                           0               2               0
# appeal to emotions                          0               2               2
# appeal to equality                          0               0               1
# appeal to reason                            0               1               0
# appeal to tradition                         0               2               0
# appeal to values                            1               3               1
# assumed knowledge                           0               1               0
# assumed legal basis                         0               1               0
# assumed threat                              0               2               0
# betrayal                                    0               1               0
# blame                                       0               3               0
# blaming                                     0               1               0
# conspiracy                                  0               7               0
# counterfactuals                             0               0               5
# demonization                                0               1               0
# direct address                              0               1               0
# doublespeak                                 0               1               0
# downplaying                                 0               3               0
# emotional language                          0               1               0
# euphemism                                   0              13               0
# evidentiality                               0               0               8
# exaggeration                                0              10               0
# false promise                               0               1               0
# fear                                        0              13               0
# fear-mongering                              0               1               0
# generalization                              0               4              15
# glittering generalities                     0               1               0
# glittering generality                       0               1               0
# intensification                             0               0              25
# labeling                                    0              14               9
# loaded language                             0               4               0
# metaphor                                    0               1               0
# misdirection                                0               2               0
# name-calling                                0               1               0
# nationalism                                 0               1               0
# negative other-presentation                 0               0              12
# number game                                 0               0               6
# polarization                                0               3               0
# positive self-presentation                  0               0               6
# presupposition                              0               0              13
# reference to authority                      0               0               1
# reference to historic events                0               0              21
# repetition                                  0               0               1
# rhetorical question                         0               1               7
# scapegoating                                0               6               0
# slanting                                    0               1               0
# stereotyping                                0               3               0
# straw man                                   0               1               0
# threat                                      0               2               0
# undermining trust                           0               1               0
# us-them                                     0               0               3
# victimhood                                  0               3               0
# victimization                               0               0               8
#
#                                 Precision  Recall   F1 Score
# accusation                            0.0     0.0   0.000000
# ad hominem                            0.0     0.0   0.000000
# appeal to a sense of community        0.0     0.0   0.000000
# appeal to authority                   0.0     0.0   0.000000
# appeal to consequences                0.0     0.0   0.000000
# appeal to emotion                     0.0     0.0   0.000000
# appeal to emotions                    0.0     0.0   0.000000
# appeal to equality                    0.0     0.0   0.000000
# appeal to reason                      0.0     0.0   0.000000
# appeal to tradition                   0.0     0.0   0.000000
# appeal to values                     25.0    50.0  33.333333
# assumed knowledge                     0.0     0.0   0.000000
# assumed legal basis                   0.0     0.0   0.000000
# assumed threat                        0.0     0.0   0.000000
# betrayal                              0.0     0.0   0.000000
# blame                                 0.0     0.0   0.000000
# blaming                               0.0     0.0   0.000000
# conspiracy                            0.0     0.0   0.000000
# counterfactuals                       0.0     0.0   0.000000
# demonization                          0.0     0.0   0.000000
# direct address                        0.0     0.0   0.000000
# doublespeak                           0.0     0.0   0.000000
# downplaying                           0.0     0.0   0.000000
# emotional language                    0.0     0.0   0.000000
# euphemism                             0.0     0.0   0.000000
# evidentiality                         0.0     0.0   0.000000
# exaggeration                          0.0     0.0   0.000000
# false promise                         0.0     0.0   0.000000
# fear                                  0.0     0.0   0.000000
# fear-mongering                        0.0     0.0   0.000000
# generalization                        0.0     0.0   0.000000
# glittering generalities               0.0     0.0   0.000000
# glittering generality                 0.0     0.0   0.000000
# intensification                       0.0     0.0   0.000000
# labeling                              0.0     0.0   0.000000
# loaded language                       0.0     0.0   0.000000
# metaphor                              0.0     0.0   0.000000
# misdirection                          0.0     0.0   0.000000
# name-calling                          0.0     0.0   0.000000
# nationalism                           0.0     0.0   0.000000
# negative other-presentation           0.0     0.0   0.000000
# number game                           0.0     0.0   0.000000
# polarization                          0.0     0.0   0.000000
# positive self-presentation            0.0     0.0   0.000000
# presupposition                        0.0     0.0   0.000000
# reference to authority                0.0     0.0   0.000000
# reference to historic events          0.0     0.0   0.000000
# repetition                            0.0     0.0   0.000000
# rhetorical question                   0.0     0.0   0.000000
# scapegoating                          0.0     0.0   0.000000
# slanting                              0.0     0.0   0.000000
# stereotyping                          0.0     0.0   0.000000
# straw man                             0.0     0.0   0.000000
# threat                                0.0     0.0   0.000000
# undermining trust                     0.0     0.0   0.000000
# us-them                               0.0     0.0   0.000000
# victimhood                            0.0     0.0   0.000000
# victimization                         0.0     0.0   0.000000
# **Weighted Precision:** 0.33333333333333337
# **Weighted Recall:** 0.6666666666666667
# **Weighted F1 Score:** 0.4444444444444444

# %%
display(Markdown(f'**Average Precision:** {np.mean([metrics[speaker]["average"][0] for speaker in metrics])}'))
display(Markdown(f'**Average Recall:** {np.mean([metrics[speaker]["average"][1] for speaker in metrics])}'))
display(Markdown(f'**Average F1 Score:** {np.mean([metrics[speaker]["average"][2] for speaker in metrics])}'))
# Out:
# **Average Precision:** 1.5673667895890118
# **Average Recall:** 2.5185185185185186
# **Average F1 Score:** 1.8683548567038197
